# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import citypy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    ## Handle API Request Errors with try-except Blocks
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bambous virieux
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | talnakh
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | luderitz
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | port hardy
# Processing Record 18 of Set 1 | comodoro rivadavia
# Processing Record 19 of Set 1 | gobabis
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | namibe
# Processing Record 22 of Set 1 | blagoveshchensk
# Processing Record 23 of Set 1 | lebu
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | sura
# Processing Record 28 of Set 1 | yeppoon
# Processing Record 29 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 1 | riyadh
# Processing Record 31 of Set 1 | kaitangata
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | grindavik
# Processing Record 34 of Set 1 | bow island
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | antibes
# Processing Record 41 of Set 1 | jinchengjiang
# City not found. Skipping...
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | henties bay
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | saldanha
# Processing Record 47 of Set 1 | kewanee
# Processing Record 48 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 1 | horadiz
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | lorengau
# Processing Record 7 of Set 2 | lyantonde
# Processing Record 8 of Set 2 | lagoa
# Processing Record 9 of Set 2 | selcuk
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | daru
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | pudem
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | adre
# Processing Record 16 of Set 2 | arrifes
# Processing Record 17 of Set 2 | tuxpan
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | geraldton
# Processing Record 20 of Set 2 | bilyayivka
# Processing Record 21 of Set 2 | sterling
# Processing Record 22 of Set 2 | kavieng
# Processing Record 23 of Set 2 | lamu
# Processing Record 24 of Set 2 | duldurga
# Processing Record 25 of Set 2 | vanavara
# Processing Record 26 of Set 2 | puerto escondido
# Processing Record 27 of Set 2 | port elizabeth
# Processing Record 28 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 2 | newport
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | hukuntsi
# Processing Record 32 of Set 2 | luganville
# Processing Record 33 of Set 2 | maneadero
# Processing Record 34 of Set 2 | bengkulu
# Processing Record 35 of Set 2 | mizpe ramon
# City not found. Skipping...
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | buala
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | tuatapere
# Processing Record 41 of Set 2 | dunedin
# Processing Record 42 of Set 2 | vostok
# Processing Record 43 of Set 2 | baykit
# Processing Record 44 of Set 2 | portland
# Processing Record 45 of Set 2 | bekhtery
# Processing Record 46 of Set 2 | kodiak
# Processing Record 47 of Set 2 | charters towers
# Processing Record 48 of Set 2 | ayagoz
# Processing Record 49 of Set 2 | olinda
# Processing Record 50 of Set 2 | faya
# Processing Record 1 of Set 3 | olafsvik
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | katsuura
# Processing Record 4 of Set 3 | chimore
# Processing Record 5 of Set 3 | narsaq
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | pryazha
# Processing Record 8 of Set 3 | lasa
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | vestmannaeyjar
# Processing Record 11 of Set 3 | ahipara
# Processing Record 12 of Set 3 | meulaboh
# Processing Record 13 of Set 3 | farafangana
# Processing Record 14 of Set 3 | dingle
# Processing Record 15 of Set 3 | san patricio
# Processing Record 16 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 3 | cherskiy
# Processing Record 18 of Set 3 | arsenyev
# Processing Record 19 of Set 3 | batagay
# Processing Record 20 of Set 3 | albany
# Processing Record 21 of Set 3 | synya
# Processing Record 22 of Set 3 | barrow
# Processing Record 23 of Set 3 | lompoc
# Processing Record 24 of Set 3 | itaituba
# Processing Record 25 of Set 3 | souillac
# Processing Record 26 of Set 3 | gavrilovka vtoraya
# Processing Record 27 of Set 3 | banamba
# Processing Record 28 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 3 | provideniya
# Processing Record 30 of Set 3 | yumen
# Processing Record 31 of Set 3 | tukrah
# Processing Record 32 of Set 3 | cockburn town
# Processing Record 33 of Set 3 | sukhobezvodnoye
# Processing Record 34 of Set 3 | fare
# Processing Record 35 of Set 3 | araouane
# Processing Record 36 of Set 3 | linda
# Processing Record 37 of Set 3 | sayyan
# Processing Record 38 of Set 3 | nueva loja
# Processing Record 39 of Set 3 | qandala
# Processing Record 40 of Set 3 | la concordia
# Processing Record 41 of Set 3 | afmadu
# City not found. Skipping...
# Processing Record 42 of Set 3 | kumher
# Processing Record 43 of Set 3 | beringovskiy
# Processing Record 44 of Set 3 | idlib
# Processing Record 45 of Set 3 | niquero
# Processing Record 46 of Set 3 | kapit
# Processing Record 47 of Set 3 | amapa
# Processing Record 48 of Set 3 | mocuba
# Processing Record 49 of Set 3 | krasnyy oktyabr
# Processing Record 50 of Set 3 | skelleftea
# Processing Record 1 of Set 4 | kuah
# Processing Record 2 of Set 4 | kita
# Processing Record 3 of Set 4 | severo-kurilsk
# Processing Record 4 of Set 4 | mangrol
# Processing Record 5 of Set 4 | codrington
# Processing Record 6 of Set 4 | bethel
# Processing Record 7 of Set 4 | seoul
# Processing Record 8 of Set 4 | juneau
# Processing Record 9 of Set 4 | sangar
# Processing Record 10 of Set 4 | georgetown
# Processing Record 11 of Set 4 | zhigansk
# Processing Record 12 of Set 4 | palaikastron
# Processing Record 13 of Set 4 | moroto
# Processing Record 14 of Set 4 | kapitanivka
# Processing Record 15 of Set 4 | termiz
# Processing Record 16 of Set 4 | vanimo
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | sumter
# Processing Record 19 of Set 4 | sao filipe
# Processing Record 20 of Set 4 | upernavik
# Processing Record 21 of Set 4 | necochea
# Processing Record 22 of Set 4 | trapani
# Processing Record 23 of Set 4 | castro
# Processing Record 24 of Set 4 | tessalit
# Processing Record 25 of Set 4 | beloha
# Processing Record 26 of Set 4 | avera
# Processing Record 27 of Set 4 | buchanan
# Processing Record 28 of Set 4 | thompson
# Processing Record 29 of Set 4 | richards bay
# Processing Record 30 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 4 | victoria
# Processing Record 32 of Set 4 | ormara
# Processing Record 33 of Set 4 | hofn
# Processing Record 34 of Set 4 | ponta delgada
# Processing Record 35 of Set 4 | alofi
# Processing Record 36 of Set 4 | ozernovskiy
# Processing Record 37 of Set 4 | salinas
# Processing Record 38 of Set 4 | bandarbeyla
# Processing Record 39 of Set 4 | arman
# Processing Record 40 of Set 4 | birao
# Processing Record 41 of Set 4 | krasnoarmeysk
# Processing Record 42 of Set 4 | bathsheba
# Processing Record 43 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 4 | iqaluit
# Processing Record 45 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 4 | norrtalje
# Processing Record 47 of Set 4 | ingham
# Processing Record 48 of Set 4 | manggar
# Processing Record 49 of Set 4 | quesnel
# Processing Record 50 of Set 4 | toppenish
# Processing Record 1 of Set 5 | hun
# Processing Record 2 of Set 5 | quatre cocos
# Processing Record 3 of Set 5 | adrar
# Processing Record 4 of Set 5 | rincon
# Processing Record 5 of Set 5 | ventspils
# Processing Record 6 of Set 5 | payakumbuh
# Processing Record 7 of Set 5 | manyana
# Processing Record 8 of Set 5 | muscat
# Processing Record 9 of Set 5 | cidreira
# Processing Record 10 of Set 5 | constitucion
# Processing Record 11 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 5 | alekseyevsk
# Processing Record 13 of Set 5 | hamilton
# Processing Record 14 of Set 5 | zalantun
# Processing Record 15 of Set 5 | clyde river
# Processing Record 16 of Set 5 | salina
# Processing Record 17 of Set 5 | honningsvag
# Processing Record 18 of Set 5 | dudinka
# Processing Record 19 of Set 5 | pangnirtung
# Processing Record 20 of Set 5 | bossembele
# City not found. Skipping...
# Processing Record 21 of Set 5 | new norfolk
# Processing Record 22 of Set 5 | albion
# Processing Record 23 of Set 5 | mulchen
# Processing Record 24 of Set 5 | grand gaube
# Processing Record 25 of Set 5 | pevek
# Processing Record 26 of Set 5 | sungairaya
# Processing Record 27 of Set 5 | te anau
# Processing Record 28 of Set 5 | gushikawa
# Processing Record 29 of Set 5 | hay river
# Processing Record 30 of Set 5 | hambantota
# Processing Record 31 of Set 5 | khandyga
# Processing Record 32 of Set 5 | luce
# Processing Record 33 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 5 | kavaratti
# Processing Record 35 of Set 5 | ancud
# Processing Record 36 of Set 5 | novi di modena
# Processing Record 37 of Set 5 | limoeiro do ajuru
# Processing Record 38 of Set 5 | kailua
# Processing Record 39 of Set 5 | luanda
# Processing Record 40 of Set 5 | harnosand
# Processing Record 41 of Set 5 | isangel
# Processing Record 42 of Set 5 | berlevag
# Processing Record 43 of Set 5 | kruisfontein
# Processing Record 44 of Set 5 | qui nhon
# Processing Record 45 of Set 5 | acapulco
# Processing Record 46 of Set 5 | gorele
# Processing Record 47 of Set 5 | yulara
# Processing Record 48 of Set 5 | ipixuna
# Processing Record 49 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 5 | pontal do parana
# Processing Record 1 of Set 6 | toucheng
# Processing Record 2 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 6 | thunder bay
# Processing Record 5 of Set 6 | zemaiciu naumiestis
# Processing Record 6 of Set 6 | warrington
# Processing Record 7 of Set 6 | havoysund
# Processing Record 8 of Set 6 | kutum
# Processing Record 9 of Set 6 | tir pol
# City not found. Skipping...
# Processing Record 10 of Set 6 | ayr
# Processing Record 11 of Set 6 | thenzawl
# Processing Record 12 of Set 6 | sitka
# Processing Record 13 of Set 6 | alamos
# Processing Record 14 of Set 6 | caldas da rainha
# Processing Record 15 of Set 6 | shelburne
# Processing Record 16 of Set 6 | dickinson
# Processing Record 17 of Set 6 | emerald
# Processing Record 18 of Set 6 | makaryev
# Processing Record 19 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 6 | placido de castro
# Processing Record 21 of Set 6 | hasaki
# Processing Record 22 of Set 6 | asau
# Processing Record 23 of Set 6 | mahibadhoo
# Processing Record 24 of Set 6 | marawi
# Processing Record 25 of Set 6 | shimoda
# Processing Record 26 of Set 6 | jumla
# Processing Record 27 of Set 6 | faanui
# Processing Record 28 of Set 6 | vila franca do campo
# Processing Record 29 of Set 6 | anadyr
# Processing Record 30 of Set 6 | saint-pierre
# Processing Record 31 of Set 6 | soc trang
# Processing Record 32 of Set 6 | praia
# Processing Record 33 of Set 6 | muros
# Processing Record 34 of Set 6 | matanzas
# Processing Record 35 of Set 6 | maceio
# Processing Record 36 of Set 6 | pangai
# Processing Record 37 of Set 6 | coos bay
# Processing Record 38 of Set 6 | torbay
# Processing Record 39 of Set 6 | zalesovo
# Processing Record 40 of Set 6 | batticaloa
# Processing Record 41 of Set 6 | odweyne
# Processing Record 42 of Set 6 | buenos aires
# Processing Record 43 of Set 6 | gigmoto
# Processing Record 44 of Set 6 | glubokoe
# City not found. Skipping...
# Processing Record 45 of Set 6 | pacific grove
# Processing Record 46 of Set 6 | high level
# Processing Record 47 of Set 6 | litovko
# Processing Record 48 of Set 6 | nanortalik
# Processing Record 49 of Set 6 | bubaque
# Processing Record 50 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 1 of Set 7 | sanger
# Processing Record 2 of Set 7 | senanga
# Processing Record 3 of Set 7 | gat
# Processing Record 4 of Set 7 | prata
# Processing Record 5 of Set 7 | dicabisagan
# Processing Record 6 of Set 7 | kirakira
# Processing Record 7 of Set 7 | orgun
# City not found. Skipping...
# Processing Record 8 of Set 7 | heihe
# Processing Record 9 of Set 7 | tres passos
# Processing Record 10 of Set 7 | huarmey
# Processing Record 11 of Set 7 | baturite
# Processing Record 12 of Set 7 | bonthe
# Processing Record 13 of Set 7 | atar
# Processing Record 14 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 7 | aklavik
# Processing Record 16 of Set 7 | matamoros
# Processing Record 17 of Set 7 | saint george
# Processing Record 18 of Set 7 | umm lajj
# Processing Record 19 of Set 7 | macapa
# Processing Record 20 of Set 7 | jessheim
# Processing Record 21 of Set 7 | soe
# Processing Record 22 of Set 7 | misratah
# Processing Record 23 of Set 7 | majene
# Processing Record 24 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 7 | realeza
# Processing Record 26 of Set 7 | sisimiut
# Processing Record 27 of Set 7 | namatanai
# Processing Record 28 of Set 7 | sorland
# Processing Record 29 of Set 7 | poronaysk
# Processing Record 30 of Set 7 | plettenberg bay
# Processing Record 31 of Set 7 | tonk
# Processing Record 32 of Set 7 | hinton
# Processing Record 33 of Set 7 | leh
# Processing Record 34 of Set 7 | ust-ishim
# Processing Record 35 of Set 7 | byron bay
# Processing Record 36 of Set 7 | bundibugyo
# Processing Record 37 of Set 7 | sabang
# Processing Record 38 of Set 7 | nelson bay
# Processing Record 39 of Set 7 | cervo
# Processing Record 40 of Set 7 | husavik
# Processing Record 41 of Set 7 | mariinsk
# Processing Record 42 of Set 7 | saint anthony
# Processing Record 43 of Set 7 | makakilo city
# Processing Record 44 of Set 7 | kovdor
# Processing Record 45 of Set 7 | tuy hoa
# Processing Record 46 of Set 7 | uchaly
# Processing Record 47 of Set 7 | mogadishu
# Processing Record 48 of Set 7 | natitingou
# Processing Record 49 of Set 7 | ziarat
# Processing Record 50 of Set 7 | jatai
# Processing Record 1 of Set 8 | chumikan
# Processing Record 2 of Set 8 | balkhash
# Processing Record 3 of Set 8 | hegang
# Processing Record 4 of Set 8 | tara
# Processing Record 5 of Set 8 | kiama
# Processing Record 6 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 8 | enshi
# Processing Record 8 of Set 8 | jalu
# Processing Record 9 of Set 8 | havelock
# Processing Record 10 of Set 8 | kaputa
# Processing Record 11 of Set 8 | fukue
# Processing Record 12 of Set 8 | mahbubnagar
# Processing Record 13 of Set 8 | paka
# Processing Record 14 of Set 8 | eureka
# Processing Record 15 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 8 | mahaicony
# City not found. Skipping...
# Processing Record 17 of Set 8 | saint-augustin
# Processing Record 18 of Set 8 | norman wells
# Processing Record 19 of Set 8 | talakan
# Processing Record 20 of Set 8 | straumen
# Processing Record 21 of Set 8 | san cristobal
# Processing Record 22 of Set 8 | tromso
# Processing Record 23 of Set 8 | klaksvik
# Processing Record 24 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 8 | broome
# Processing Record 26 of Set 8 | taltal
# Processing Record 27 of Set 8 | esperance
# Processing Record 28 of Set 8 | samarai
# Processing Record 29 of Set 8 | noumea
# Processing Record 30 of Set 8 | takayama
# Processing Record 31 of Set 8 | los llanos de aridane
# Processing Record 32 of Set 8 | manglaur
# Processing Record 33 of Set 8 | maykor
# Processing Record 34 of Set 8 | kahului
# Processing Record 35 of Set 8 | fortuna
# Processing Record 36 of Set 8 | dawlatabad
# Processing Record 37 of Set 8 | wewak
# Processing Record 38 of Set 8 | poum
# Processing Record 39 of Set 8 | kalmunai
# Processing Record 40 of Set 8 | bardiyah
# Processing Record 41 of Set 8 | falaleu
# City not found. Skipping...
# Processing Record 42 of Set 8 | sibolga
# Processing Record 43 of Set 8 | high rock
# Processing Record 44 of Set 8 | kalynivka
# Processing Record 45 of Set 8 | zhuhai
# Processing Record 46 of Set 8 | darayya
# Processing Record 47 of Set 8 | abu samrah
# Processing Record 48 of Set 8 | santa cruz
# Processing Record 49 of Set 8 | ust-omchug
# Processing Record 50 of Set 8 | santa rosa
# Processing Record 1 of Set 9 | inzhavino
# Processing Record 2 of Set 9 | gamba
# Processing Record 3 of Set 9 | ordu
# Processing Record 4 of Set 9 | pyaozerskiy
# Processing Record 5 of Set 9 | teguldet
# Processing Record 6 of Set 9 | hami
# Processing Record 7 of Set 9 | touros
# Processing Record 8 of Set 9 | hobe sound
# Processing Record 9 of Set 9 | marsh harbour
# Processing Record 10 of Set 9 | caravelas
# Processing Record 11 of Set 9 | aksu
# Processing Record 12 of Set 9 | mikuni
# Processing Record 13 of Set 9 | bousso
# Processing Record 14 of Set 9 | manta
# Processing Record 15 of Set 9 | dukat
# Processing Record 16 of Set 9 | inirida
# Processing Record 17 of Set 9 | komsomolskiy
# Processing Record 18 of Set 9 | walvis bay
# Processing Record 19 of Set 9 | rio grande
# Processing Record 20 of Set 9 | airai
# Processing Record 21 of Set 9 | nuuk
# Processing Record 22 of Set 9 | sindor
# Processing Record 23 of Set 9 | chilca
# Processing Record 24 of Set 9 | oltu
# Processing Record 25 of Set 9 | onguday
# Processing Record 26 of Set 9 | chapais
# Processing Record 27 of Set 9 | mareeba
# Processing Record 28 of Set 9 | muromtsevo
# Processing Record 29 of Set 9 | tazovskiy
# Processing Record 30 of Set 9 | along
# Processing Record 31 of Set 9 | barddhaman
# Processing Record 32 of Set 9 | muzhi
# Processing Record 33 of Set 9 | rawson
# Processing Record 34 of Set 9 | saint-georges
# Processing Record 35 of Set 9 | rupert
# Processing Record 36 of Set 9 | mount pleasant
# Processing Record 37 of Set 9 | ostrovnoy
# Processing Record 38 of Set 9 | camacari
# Processing Record 39 of Set 9 | taungdwingyi
# Processing Record 40 of Set 9 | omboue
# Processing Record 41 of Set 9 | kuantan
# Processing Record 42 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 9 | shitanjing
# Processing Record 44 of Set 9 | laplace
# Processing Record 45 of Set 9 | general roca
# Processing Record 46 of Set 9 | canchungo
# Processing Record 47 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 48 of Set 9 | ust-barguzin
# Processing Record 49 of Set 9 | honiara
# Processing Record 50 of Set 9 | pak phanang
# Processing Record 1 of Set 10 | lavrentiya
# Processing Record 2 of Set 10 | tres picos
# Processing Record 3 of Set 10 | popondetta
# Processing Record 4 of Set 10 | broken hill
# Processing Record 5 of Set 10 | bandiagara
# Processing Record 6 of Set 10 | burica
# City not found. Skipping...
# Processing Record 7 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 8 of Set 10 | nazarovo
# Processing Record 9 of Set 10 | kasempa
# Processing Record 10 of Set 10 | ghauspur
# Processing Record 11 of Set 10 | verkhnyaya toyma
# Processing Record 12 of Set 10 | xining
# Processing Record 13 of Set 10 | fairbanks
# Processing Record 14 of Set 10 | laela
# Processing Record 15 of Set 10 | hue
# Processing Record 16 of Set 10 | ekibastuz
# Processing Record 17 of Set 10 | chuy
# Processing Record 18 of Set 10 | arona
# Processing Record 19 of Set 10 | lingao
# Processing Record 20 of Set 10 | shahdadkot
# Processing Record 21 of Set 10 | florianopolis
# Processing Record 22 of Set 10 | pisco
# Processing Record 23 of Set 10 | topolobampo
# Processing Record 24 of Set 10 | ubinskoye
# Processing Record 25 of Set 10 | kuching
# Processing Record 26 of Set 10 | suez
# Processing Record 27 of Set 10 | tautira
# Processing Record 28 of Set 10 | ugoofaaru
# Processing Record 29 of Set 10 | padang
# Processing Record 30 of Set 10 | grants
# Processing Record 31 of Set 10 | saint-joseph
# Processing Record 32 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 33 of Set 10 | akyab
# Processing Record 34 of Set 10 | brownfield
# Processing Record 35 of Set 10 | bastrop
# Processing Record 36 of Set 10 | monrovia
# Processing Record 37 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 10 | davila
# Processing Record 39 of Set 10 | umm kaddadah
# Processing Record 40 of Set 10 | deputatskiy
# Processing Record 41 of Set 10 | santa maria
# Processing Record 42 of Set 10 | agadir
# Processing Record 43 of Set 10 | baherden
# Processing Record 44 of Set 10 | lincoln
# Processing Record 45 of Set 10 | banjar
# Processing Record 46 of Set 10 | bonavista
# Processing Record 47 of Set 10 | inhambane
# Processing Record 48 of Set 10 | alice springs
# Processing Record 49 of Set 10 | vicuna
# Processing Record 50 of Set 10 | skibbereen
# Processing Record 1 of Set 11 | sinjai
# Processing Record 2 of Set 11 | monitos
# Processing Record 3 of Set 11 | zvishavane
# Processing Record 4 of Set 11 | erzin
# Processing Record 5 of Set 11 | benghazi
# Processing Record 6 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 11 | bajil
# Processing Record 8 of Set 11 | vredendal
# Processing Record 9 of Set 11 | port hedland
# Processing Record 10 of Set 11 | stokmarknes
# Processing Record 11 of Set 11 | calama
# Processing Record 12 of Set 11 | oriximina
# Processing Record 13 of Set 11 | chipinge
# Processing Record 14 of Set 11 | mountain home
# Processing Record 15 of Set 11 | lata
# Processing Record 16 of Set 11 | marihatag
# Processing Record 17 of Set 11 | takoradi
# Processing Record 18 of Set 11 | ashland
# Processing Record 19 of Set 11 | ilulissat
# Processing Record 20 of Set 11 | okhotsk
# Processing Record 21 of Set 11 | ikom
# Processing Record 22 of Set 11 | porto novo
# Processing Record 23 of Set 11 | sistranda
# Processing Record 24 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 25 of Set 11 | okahandja
# Processing Record 26 of Set 11 | cayenne
# Processing Record 27 of Set 11 | hastings
# Processing Record 28 of Set 11 | paltinis
# Processing Record 29 of Set 11 | french harbor
# Processing Record 30 of Set 11 | effingham
# Processing Record 31 of Set 11 | nemuro
# Processing Record 32 of Set 11 | kununurra
# Processing Record 33 of Set 11 | kiunga
# Processing Record 34 of Set 11 | unai
# Processing Record 35 of Set 11 | korla
# Processing Record 36 of Set 11 | port macquarie
# Processing Record 37 of Set 11 | teguise
# Processing Record 38 of Set 11 | weinan
# Processing Record 39 of Set 11 | shache
# Processing Record 40 of Set 11 | ayan
# Processing Record 41 of Set 11 | ler
# Processing Record 42 of Set 11 | leshukonskoye
# Processing Record 43 of Set 11 | cabo san lucas
# Processing Record 44 of Set 11 | altay
# Processing Record 45 of Set 11 | punta alta
# Processing Record 46 of Set 11 | ayna
# Processing Record 47 of Set 11 | anna
# Processing Record 48 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 11 | kotido
# Processing Record 50 of Set 11 | kirkwall
# Processing Record 1 of Set 12 | khakhea
# Processing Record 2 of Set 12 | solnechnyy
# Processing Record 3 of Set 12 | lekoni
# Processing Record 4 of Set 12 | kysyl-syr
# Processing Record 5 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 6 of Set 12 | flin flon
# Processing Record 7 of Set 12 | san miguel
# Processing Record 8 of Set 12 | chivacoa
# Processing Record 9 of Set 12 | mukono
# Processing Record 10 of Set 12 | jiaojiang
# Processing Record 11 of Set 12 | mackenzie
# Processing Record 12 of Set 12 | ondjiva
# Processing Record 13 of Set 12 | macia
# Processing Record 14 of Set 12 | neiafu
# Processing Record 15 of Set 12 | mirnyy
# Processing Record 16 of Set 12 | casablanca
# Processing Record 17 of Set 12 | najran
# Processing Record 18 of Set 12 | sinjar
# Processing Record 19 of Set 12 | naliya
# Processing Record 20 of Set 12 | el bagre
# Processing Record 21 of Set 12 | wote
# Processing Record 22 of Set 12 | wattegama
# Processing Record 23 of Set 12 | jaisalmer
# Processing Record 24 of Set 12 | leningradskiy
# Processing Record 25 of Set 12 | zhangye
# Processing Record 26 of Set 12 | emirdag
# Processing Record 27 of Set 12 | lakes entrance
# Processing Record 28 of Set 12 | brae
# Processing Record 29 of Set 12 | dhidhdhoo
# Processing Record 30 of Set 12 | casambalangan
# Processing Record 31 of Set 12 | marrakesh
# Processing Record 32 of Set 12 | alihe
# Processing Record 33 of Set 12 | maniitsoq
# Processing Record 34 of Set 12 | sola
# Processing Record 35 of Set 12 | tselinnoye
# Processing Record 36 of Set 12 | kichera
# Processing Record 37 of Set 12 | caorle
# Processing Record 38 of Set 12 | atherton
# Processing Record 39 of Set 12 | terracina
# Processing Record 40 of Set 12 | andenes
# Processing Record 41 of Set 12 | itarema
# Processing Record 42 of Set 12 | bambanglipuro
# Processing Record 43 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 12 | fort-shevchenko
# Processing Record 45 of Set 12 | upata
# Processing Record 46 of Set 12 | amurzet
# Processing Record 47 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 12 | kloulklubed
# Processing Record 49 of Set 12 | kaeo
# Processing Record 50 of Set 12 | vila velha
# Processing Record 1 of Set 13 | mount gambier
# Processing Record 2 of Set 13 | ranong
# Processing Record 3 of Set 13 | port lincoln
# Processing Record 4 of Set 13 | george town
# Processing Record 5 of Set 13 | mnogovershinnyy
# Processing Record 6 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 13 | sao miguel do araguaia
# Processing Record 8 of Set 13 | rudbar
# Processing Record 9 of Set 13 | soria
# Processing Record 10 of Set 13 | chimbote
# Processing Record 11 of Set 13 | tandil
# Processing Record 12 of Set 13 | arlit
# Processing Record 13 of Set 13 | udachnyy
# Processing Record 14 of Set 13 | baruun-urt
# Processing Record 15 of Set 13 | aguas formosas
# Processing Record 16 of Set 13 | tura
# Processing Record 17 of Set 13 | pasni
# Processing Record 18 of Set 13 | coria
# Processing Record 19 of Set 13 | himora
# City not found. Skipping...
# Processing Record 20 of Set 13 | marzuq
# Processing Record 21 of Set 13 | ambon
# Processing Record 22 of Set 13 | mackay
# Processing Record 23 of Set 13 | nyurba
# Processing Record 24 of Set 13 | abu dhabi
# Processing Record 25 of Set 13 | puerto penasco
# Processing Record 26 of Set 13 | gap
# Processing Record 27 of Set 13 | manzanillo
# Processing Record 28 of Set 13 | valdivia
# Processing Record 29 of Set 13 | camacha
# Processing Record 30 of Set 13 | the valley
# Processing Record 31 of Set 13 | springdale
# Processing Record 32 of Set 13 | natal
# Processing Record 33 of Set 13 | arys
# Processing Record 34 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 13 | gander
# Processing Record 36 of Set 13 | lady frere
# Processing Record 37 of Set 13 | shubarkuduk
# Processing Record 38 of Set 13 | severn
# Processing Record 39 of Set 13 | lensk
# Processing Record 40 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 41 of Set 13 | laguna
# Processing Record 42 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 13 | koungheul
# Processing Record 44 of Set 13 | sidi qasim
# City not found. Skipping...
# Processing Record 45 of Set 13 | prince rupert
# Processing Record 46 of Set 13 | neuquen
# Processing Record 47 of Set 13 | kampong thum
# Processing Record 48 of Set 13 | mandalgovi
# Processing Record 49 of Set 13 | rundu
# Processing Record 50 of Set 13 | linjiang
# Processing Record 1 of Set 14 | adet
# Processing Record 2 of Set 14 | muisne
# Processing Record 3 of Set 14 | bahia blanca
# Processing Record 4 of Set 14 | evensk
# Processing Record 5 of Set 14 | waiuku
# Processing Record 6 of Set 14 | kaitong
# Processing Record 7 of Set 14 | phonhong
# Processing Record 8 of Set 14 | sur
# Processing Record 9 of Set 14 | pundaguitan
# Processing Record 10 of Set 14 | kawardha
# Processing Record 11 of Set 14 | blind river
# Processing Record 12 of Set 14 | pathein
# Processing Record 13 of Set 14 | nagato
# Processing Record 14 of Set 14 | sarakhs
# Processing Record 15 of Set 14 | worthington
# Processing Record 16 of Set 14 | bayangol
# Processing Record 17 of Set 14 | bollnas
# Processing Record 18 of Set 14 | molina
# Processing Record 19 of Set 14 | bumba
# Processing Record 20 of Set 14 | candolim
# Processing Record 21 of Set 14 | camacupa
# Processing Record 22 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 23 of Set 14 | severo-yeniseyskiy
# Processing Record 24 of Set 14 | shingu
# Processing Record 25 of Set 14 | mishelevka
# Processing Record 26 of Set 14 | inuvik
# Processing Record 27 of Set 14 | qesarya
# Processing Record 28 of Set 14 | namie
# Processing Record 29 of Set 14 | kishtwar
# Processing Record 30 of Set 14 | sinnamary
# Processing Record 31 of Set 14 | tra vinh
# Processing Record 32 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 14 | salalah
# Processing Record 34 of Set 14 | sambava
# Processing Record 35 of Set 14 | tiarei
# Processing Record 36 of Set 14 | cortes
# Processing Record 37 of Set 14 | nome
# Processing Record 38 of Set 14 | brookings
# Processing Record 39 of Set 14 | kasongo-lunda
# Processing Record 40 of Set 14 | fort nelson
# Processing Record 41 of Set 14 | tambilil
# Processing Record 42 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 43 of Set 14 | ahuimanu
# Processing Record 44 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 14 | maniwaki
# Processing Record 46 of Set 14 | sitio novo do tocantins
# Processing Record 47 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 48 of Set 14 | miranda
# Processing Record 49 of Set 14 | kyra
# Processing Record 50 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 15 | carutapera
# Processing Record 3 of Set 15 | nannilam
# Processing Record 4 of Set 15 | batagay-alyta
# Processing Record 5 of Set 15 | crestview
# Processing Record 6 of Set 15 | naze
# Processing Record 7 of Set 15 | sorong
# Processing Record 8 of Set 15 | vardo
# Processing Record 9 of Set 15 | suleya
# Processing Record 10 of Set 15 | mayo
# Processing Record 11 of Set 15 | kapiri mposhi

# %%
len(city_data)
# Out:
# 687

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bambous Virieux      MU -20.3428   57.7575     77.22        68         100
# 1     Puerto Ayora      EC  -0.7393  -90.3518     80.56        91          98
# 2          Talnakh      RU  69.4865   88.3972    -19.61        87         100
# 3    Mar Del Plata      AR -38.0023  -57.5575     72.88        83         100
# 4            Vaini      TO -21.2000 -175.2000     77.36        80          19
# 5         Luderitz      NA -26.6481   15.1594     63.28        82           2
# 6          Mataura      NZ -46.1927  168.8643     49.21        81         100
# 7           Hobart      AU -42.8794  147.3294     49.26        85          75
# 8         Tasiilaq      GL  65.6145  -37.6368     35.76        70         100
# 9      Yellowknife      CA  62.4560 -114.3525     10.42        91         100
#
#    Wind Speed Current Description
# 0       14.67     overcast clouds
# 1        5.01     overcast clouds
# 2        1.23     overcast clouds
# 3        7.00     overcast clouds
# 4       16.98          light rain
# 5       13.78           clear sky
# 6        0.56     overcast clouds
# 7        8.05       broken clouds
# 8       19.73     overcast clouds
# 9       10.00     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
