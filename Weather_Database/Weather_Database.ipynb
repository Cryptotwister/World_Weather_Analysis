# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import citypy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    ## Handle API Request Errors with try-except Blocks
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lagoa
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | yatou
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | ugra
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | kloulklubed
# Processing Record 10 of Set 1 | kolondieba
# Processing Record 11 of Set 1 | palana
# Processing Record 12 of Set 1 | mehamn
# Processing Record 13 of Set 1 | haicheng
# Processing Record 14 of Set 1 | katangli
# Processing Record 15 of Set 1 | ust-karsk
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | severo-yeniseyskiy
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | sao felix do xingu
# Processing Record 22 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | sao filipe
# Processing Record 25 of Set 1 | gamba
# Processing Record 26 of Set 1 | merauke
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | yaroslavskaya
# Processing Record 29 of Set 1 | conceicao do araguaia
# Processing Record 30 of Set 1 | tazovskiy
# Processing Record 31 of Set 1 | bushehr
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | kirakira
# Processing Record 36 of Set 1 | eisiskes
# Processing Record 37 of Set 1 | tautira
# Processing Record 38 of Set 1 | skibbereen
# Processing Record 39 of Set 1 | sinnamary
# Processing Record 40 of Set 1 | fortuna
# Processing Record 41 of Set 1 | fort nelson
# Processing Record 42 of Set 1 | fethiye
# Processing Record 43 of Set 1 | bosaso
# Processing Record 44 of Set 1 | constitucion
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | lompoc
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | port blair
# Processing Record 2 of Set 2 | longyearbyen
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | humaita
# Processing Record 5 of Set 2 | kysucke nove mesto
# Processing Record 6 of Set 2 | la union
# Processing Record 7 of Set 2 | pevek
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | sorada
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | vila franca do campo
# Processing Record 12 of Set 2 | nabire
# Processing Record 13 of Set 2 | victoria
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | qaqortoq
# Processing Record 17 of Set 2 | biltine
# Processing Record 18 of Set 2 | bo rai
# Processing Record 19 of Set 2 | kajaani
# Processing Record 20 of Set 2 | awjilah
# Processing Record 21 of Set 2 | pangody
# Processing Record 22 of Set 2 | araouane
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | belmonte
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | hanover
# Processing Record 27 of Set 2 | padang
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | thurso
# Processing Record 30 of Set 2 | sur
# Processing Record 31 of Set 2 | pailon
# Processing Record 32 of Set 2 | sao joao da barra
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | porto novo
# Processing Record 36 of Set 2 | norman wells
# Processing Record 37 of Set 2 | lakatoro
# Processing Record 38 of Set 2 | puerto ayora
# Processing Record 39 of Set 2 | katsuura
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | riyadh
# Processing Record 42 of Set 2 | bokoro
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | vaitape
# Processing Record 47 of Set 2 | cam ranh
# Processing Record 48 of Set 2 | maputo
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | fukuma
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | guangyuan
# Processing Record 3 of Set 3 | luderitz
# Processing Record 4 of Set 3 | roald
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | dongsheng
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | makakilo city
# Processing Record 13 of Set 3 | arona
# Processing Record 14 of Set 3 | kholmogory
# Processing Record 15 of Set 3 | port-cartier
# Processing Record 16 of Set 3 | komsomolskiy
# Processing Record 17 of Set 3 | ankang
# Processing Record 18 of Set 3 | kirkwall
# Processing Record 19 of Set 3 | ashland
# Processing Record 20 of Set 3 | phan thiet
# Processing Record 21 of Set 3 | airai
# Processing Record 22 of Set 3 | melilla
# Processing Record 23 of Set 3 | borogontsy
# Processing Record 24 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 3 | muisne
# Processing Record 26 of Set 3 | itambe
# Processing Record 27 of Set 3 | nome
# Processing Record 28 of Set 3 | georgetown
# Processing Record 29 of Set 3 | lavrentiya
# Processing Record 30 of Set 3 | alice springs
# Processing Record 31 of Set 3 | mildura
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | alofi
# Processing Record 34 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 3 | barabai
# Processing Record 36 of Set 3 | zelenchukskaya
# Processing Record 37 of Set 3 | atuona
# Processing Record 38 of Set 3 | havre-saint-pierre
# Processing Record 39 of Set 3 | pontianak
# Processing Record 40 of Set 3 | yurga
# Processing Record 41 of Set 3 | lucapa
# Processing Record 42 of Set 3 | esmeraldas
# Processing Record 43 of Set 3 | pierre
# Processing Record 44 of Set 3 | thompson
# Processing Record 45 of Set 3 | vao
# Processing Record 46 of Set 3 | bluff
# Processing Record 47 of Set 3 | uwajima
# Processing Record 48 of Set 3 | waingapu
# Processing Record 49 of Set 3 | karasburg
# Processing Record 50 of Set 3 | mount isa
# Processing Record 1 of Set 4 | evensk
# Processing Record 2 of Set 4 | salalah
# Processing Record 3 of Set 4 | yingkou
# Processing Record 4 of Set 4 | hermanus
# Processing Record 5 of Set 4 | vestmannaeyjar
# Processing Record 6 of Set 4 | ketchikan
# Processing Record 7 of Set 4 | auki
# Processing Record 8 of Set 4 | kruisfontein
# Processing Record 9 of Set 4 | aden
# Processing Record 10 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 4 | agirish
# Processing Record 12 of Set 4 | barrow
# Processing Record 13 of Set 4 | provideniya
# Processing Record 14 of Set 4 | wentzville
# Processing Record 15 of Set 4 | poso
# Processing Record 16 of Set 4 | esfarayen
# Processing Record 17 of Set 4 | lastoursville
# Processing Record 18 of Set 4 | severo-kurilsk
# Processing Record 19 of Set 4 | khatanga
# Processing Record 20 of Set 4 | mizan teferi
# Processing Record 21 of Set 4 | saskylakh
# Processing Record 22 of Set 4 | talnakh
# Processing Record 23 of Set 4 | port moresby
# Processing Record 24 of Set 4 | bredasdorp
# Processing Record 25 of Set 4 | namibe
# Processing Record 26 of Set 4 | streator
# Processing Record 27 of Set 4 | kamenka
# Processing Record 28 of Set 4 | balakhninskiy
# Processing Record 29 of Set 4 | lidzbark warminski
# Processing Record 30 of Set 4 | honningsvag
# Processing Record 31 of Set 4 | tolaga bay
# Processing Record 32 of Set 4 | mitu
# Processing Record 33 of Set 4 | pedernales
# Processing Record 34 of Set 4 | camalu
# Processing Record 35 of Set 4 | guerrero negro
# Processing Record 36 of Set 4 | kavieng
# Processing Record 37 of Set 4 | ponta do sol
# Processing Record 38 of Set 4 | kavaratti
# Processing Record 39 of Set 4 | mahuta
# Processing Record 40 of Set 4 | tiksi
# Processing Record 41 of Set 4 | montevideo
# Processing Record 42 of Set 4 | sivaki
# Processing Record 43 of Set 4 | alihe
# Processing Record 44 of Set 4 | bambous virieux
# Processing Record 45 of Set 4 | hwange
# Processing Record 46 of Set 4 | sola
# Processing Record 47 of Set 4 | cayenne
# Processing Record 48 of Set 4 | chumikan
# Processing Record 49 of Set 4 | sindor
# Processing Record 50 of Set 4 | lasa
# Processing Record 1 of Set 5 | moron
# Processing Record 2 of Set 5 | yulara
# Processing Record 3 of Set 5 | burns lake
# Processing Record 4 of Set 5 | poltavka
# Processing Record 5 of Set 5 | aklavik
# Processing Record 6 of Set 5 | saint george
# Processing Record 7 of Set 5 | shimoda
# Processing Record 8 of Set 5 | urumqi
# Processing Record 9 of Set 5 | ostrovnoy
# Processing Record 10 of Set 5 | acarau
# Processing Record 11 of Set 5 | husavik
# Processing Record 12 of Set 5 | kulhudhuffushi
# Processing Record 13 of Set 5 | bethel
# Processing Record 14 of Set 5 | bayanday
# Processing Record 15 of Set 5 | teahupoo
# Processing Record 16 of Set 5 | tepetitla
# Processing Record 17 of Set 5 | road town
# Processing Record 18 of Set 5 | mafinga
# Processing Record 19 of Set 5 | inta
# Processing Record 20 of Set 5 | berdigestyakh
# Processing Record 21 of Set 5 | turukhansk
# Processing Record 22 of Set 5 | atbasar
# Processing Record 23 of Set 5 | san cristobal
# Processing Record 24 of Set 5 | jamestown
# Processing Record 25 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 5 | kodinsk
# Processing Record 27 of Set 5 | ixtapa
# Processing Record 28 of Set 5 | jacareacanga
# Processing Record 29 of Set 5 | coquimbo
# Processing Record 30 of Set 5 | pundaguitan
# Processing Record 31 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 5 | taltal
# Processing Record 33 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 5 | sao miguel do araguaia
# Processing Record 35 of Set 5 | zaida
# Processing Record 36 of Set 5 | ust-maya
# Processing Record 37 of Set 5 | wanning
# Processing Record 38 of Set 5 | igarape-acu
# City not found. Skipping...
# Processing Record 39 of Set 5 | srednekolymsk
# Processing Record 40 of Set 5 | santa marta
# Processing Record 41 of Set 5 | ayan
# Processing Record 42 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 5 | khagrachari
# City not found. Skipping...
# Processing Record 44 of Set 5 | mbandaka
# Processing Record 45 of Set 5 | opunake
# Processing Record 46 of Set 5 | nyurba
# Processing Record 47 of Set 5 | karratha
# Processing Record 48 of Set 5 | ancud
# Processing Record 49 of Set 5 | zhigansk
# Processing Record 50 of Set 5 | meulaboh
# Processing Record 1 of Set 6 | san quintin
# Processing Record 2 of Set 6 | zmiyiv
# Processing Record 3 of Set 6 | khandyga
# Processing Record 4 of Set 6 | sisimiut
# Processing Record 5 of Set 6 | bay roberts
# Processing Record 6 of Set 6 | zaraza
# Processing Record 7 of Set 6 | ankazobe
# Processing Record 8 of Set 6 | nago
# Processing Record 9 of Set 6 | te anau
# Processing Record 10 of Set 6 | dzaoudzi
# Processing Record 11 of Set 6 | viedma
# Processing Record 12 of Set 6 | barra do bugres
# Processing Record 13 of Set 6 | kaeo
# Processing Record 14 of Set 6 | aksu
# Processing Record 15 of Set 6 | mandalgovi
# Processing Record 16 of Set 6 | les cayes
# Processing Record 17 of Set 6 | funadhoo
# Processing Record 18 of Set 6 | farakka
# Processing Record 19 of Set 6 | conakry
# Processing Record 20 of Set 6 | codrington
# Processing Record 21 of Set 6 | clyde river
# Processing Record 22 of Set 6 | itoman
# Processing Record 23 of Set 6 | valdez
# Processing Record 24 of Set 6 | pisco
# Processing Record 25 of Set 6 | nanortalik
# Processing Record 26 of Set 6 | anloga
# Processing Record 27 of Set 6 | leo
# Processing Record 28 of Set 6 | takoradi
# Processing Record 29 of Set 6 | coracora
# Processing Record 30 of Set 6 | verkhoyansk
# Processing Record 31 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 6 | kirkwood
# Processing Record 33 of Set 6 | bossembele
# City not found. Skipping...
# Processing Record 34 of Set 6 | asau
# Processing Record 35 of Set 6 | valley city
# Processing Record 36 of Set 6 | mombetsu
# Processing Record 37 of Set 6 | effium
# Processing Record 38 of Set 6 | carutapera
# Processing Record 39 of Set 6 | bilma
# Processing Record 40 of Set 6 | manggar
# Processing Record 41 of Set 6 | pangoa
# Processing Record 42 of Set 6 | sibolga
# Processing Record 43 of Set 6 | gillette
# Processing Record 44 of Set 6 | santa fe
# Processing Record 45 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 6 | goderich
# Processing Record 47 of Set 6 | dunedin
# Processing Record 48 of Set 6 | savonlinna
# Processing Record 49 of Set 6 | sheridan
# Processing Record 50 of Set 6 | golyshmanovo
# Processing Record 1 of Set 7 | wah
# Processing Record 2 of Set 7 | pekan
# Processing Record 3 of Set 7 | mahaicony
# City not found. Skipping...
# Processing Record 4 of Set 7 | mapiripan
# Processing Record 5 of Set 7 | marsa matruh
# Processing Record 6 of Set 7 | cordoba
# Processing Record 7 of Set 7 | baruun-urt
# Processing Record 8 of Set 7 | sint-truiden
# Processing Record 9 of Set 7 | santa vitoria
# Processing Record 10 of Set 7 | alenquer
# Processing Record 11 of Set 7 | yerbogachen
# Processing Record 12 of Set 7 | siofok
# Processing Record 13 of Set 7 | pangnirtung
# Processing Record 14 of Set 7 | abnub
# Processing Record 15 of Set 7 | northam
# Processing Record 16 of Set 7 | samarai
# Processing Record 17 of Set 7 | faya
# Processing Record 18 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 7 | peniche
# Processing Record 20 of Set 7 | huambo
# Processing Record 21 of Set 7 | berlevag
# Processing Record 22 of Set 7 | iqaluit
# Processing Record 23 of Set 7 | cidreira
# Processing Record 24 of Set 7 | shenjiamen
# Processing Record 25 of Set 7 | susangerd
# Processing Record 26 of Set 7 | mwinilunga
# Processing Record 27 of Set 7 | kang
# Processing Record 28 of Set 7 | gobabis
# Processing Record 29 of Set 7 | bathsheba
# Processing Record 30 of Set 7 | samfya
# Processing Record 31 of Set 7 | dali
# Processing Record 32 of Set 7 | srandakan
# Processing Record 33 of Set 7 | bandarbeyla
# Processing Record 34 of Set 7 | vila do maio
# Processing Record 35 of Set 7 | broome
# Processing Record 36 of Set 7 | dingle
# Processing Record 37 of Set 7 | sao gabriel da cachoeira
# Processing Record 38 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 39 of Set 7 | san patricio
# Processing Record 40 of Set 7 | tefe
# Processing Record 41 of Set 7 | shenkursk
# Processing Record 42 of Set 7 | nantucket
# Processing Record 43 of Set 7 | anadyr
# Processing Record 44 of Set 7 | bambanglipuro
# Processing Record 45 of Set 7 | guiratinga
# Processing Record 46 of Set 7 | koumac
# Processing Record 47 of Set 7 | aldan
# Processing Record 48 of Set 7 | aksarka
# Processing Record 49 of Set 7 | klaksvik
# Processing Record 50 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 2 of Set 8 | russell
# Processing Record 3 of Set 8 | shaunavon
# Processing Record 4 of Set 8 | burica
# City not found. Skipping...
# Processing Record 5 of Set 8 | kieta
# Processing Record 6 of Set 8 | winnemucca
# Processing Record 7 of Set 8 | ahipara
# Processing Record 8 of Set 8 | iguala
# Processing Record 9 of Set 8 | comodoro rivadavia
# Processing Record 10 of Set 8 | walvis bay
# Processing Record 11 of Set 8 | novoagansk
# Processing Record 12 of Set 8 | waterloo
# Processing Record 13 of Set 8 | tateyama
# Processing Record 14 of Set 8 | doha
# Processing Record 15 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 8 | broken hill
# Processing Record 17 of Set 8 | hualmay
# Processing Record 18 of Set 8 | tarko-sale
# Processing Record 19 of Set 8 | korhogo
# Processing Record 20 of Set 8 | cockburn town
# Processing Record 21 of Set 8 | quatre cocos
# Processing Record 22 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 8 | ouesso
# Processing Record 24 of Set 8 | pathein
# Processing Record 25 of Set 8 | sukumo
# Processing Record 26 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 8 | atasu
# Processing Record 28 of Set 8 | rocha
# Processing Record 29 of Set 8 | otradnoye
# Processing Record 30 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 8 | bengkulu
# Processing Record 32 of Set 8 | coihaique
# Processing Record 33 of Set 8 | dharmabad
# Processing Record 34 of Set 8 | gorgan
# Processing Record 35 of Set 8 | waipawa
# Processing Record 36 of Set 8 | mattru
# Processing Record 37 of Set 8 | pitimbu
# Processing Record 38 of Set 8 | hambantota
# Processing Record 39 of Set 8 | bagotville
# Processing Record 40 of Set 8 | lake cowichan
# Processing Record 41 of Set 8 | altayskoye
# Processing Record 42 of Set 8 | rochegda
# Processing Record 43 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 8 | saldanha
# Processing Record 45 of Set 8 | okhotsk
# Processing Record 46 of Set 8 | jinan
# Processing Record 47 of Set 8 | hofn
# Processing Record 48 of Set 8 | miastko
# Processing Record 49 of Set 8 | staroaleyskoye
# Processing Record 50 of Set 8 | tsaratanana
# Processing Record 1 of Set 9 | haines junction
# Processing Record 2 of Set 9 | odesskoye
# Processing Record 3 of Set 9 | ugoofaaru
# Processing Record 4 of Set 9 | isangel
# Processing Record 5 of Set 9 | ulladulla
# Processing Record 6 of Set 9 | adelaide
# Processing Record 7 of Set 9 | skelleftea
# Processing Record 8 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 9 | kupang
# Processing Record 10 of Set 9 | strezhevoy
# Processing Record 11 of Set 9 | dabhol
# Processing Record 12 of Set 9 | jurmala
# Processing Record 13 of Set 9 | tuatapere
# Processing Record 14 of Set 9 | laguna
# Processing Record 15 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 16 of Set 9 | miracema do tocantins
# Processing Record 17 of Set 9 | bantry
# Processing Record 18 of Set 9 | micheweni
# Processing Record 19 of Set 9 | mehran
# Processing Record 20 of Set 9 | santa margherita ligure
# Processing Record 21 of Set 9 | bilibino
# Processing Record 22 of Set 9 | moerai
# Processing Record 23 of Set 9 | tsienyane
# City not found. Skipping...
# Processing Record 24 of Set 9 | kaoma
# Processing Record 25 of Set 9 | grants
# Processing Record 26 of Set 9 | helena
# Processing Record 27 of Set 9 | travesia
# Processing Record 28 of Set 9 | sarrebourg
# Processing Record 29 of Set 9 | coos bay
# Processing Record 30 of Set 9 | lixourion
# Processing Record 31 of Set 9 | tocopilla
# Processing Record 32 of Set 9 | marinette
# Processing Record 33 of Set 9 | hammond
# Processing Record 34 of Set 9 | amga
# Processing Record 35 of Set 9 | gizo
# Processing Record 36 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 9 | kedougou
# Processing Record 38 of Set 9 | lisakovsk
# Processing Record 39 of Set 9 | zhezkazgan
# Processing Record 40 of Set 9 | diamantino
# Processing Record 41 of Set 9 | ampanihy
# Processing Record 42 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 43 of Set 9 | weligama
# Processing Record 44 of Set 9 | poum
# Processing Record 45 of Set 9 | altay
# Processing Record 46 of Set 9 | manuk mangkaw
# Processing Record 47 of Set 9 | carnarvon
# Processing Record 48 of Set 9 | champerico
# Processing Record 49 of Set 9 | antalaha
# Processing Record 50 of Set 9 | bud
# Processing Record 1 of Set 10 | vardo
# Processing Record 2 of Set 10 | rio grande
# Processing Record 3 of Set 10 | luanda
# Processing Record 4 of Set 10 | esperance
# Processing Record 5 of Set 10 | la sarre
# Processing Record 6 of Set 10 | sabang
# Processing Record 7 of Set 10 | yuancheng
# Processing Record 8 of Set 10 | porto walter
# Processing Record 9 of Set 10 | kerema
# Processing Record 10 of Set 10 | roberto payan
# City not found. Skipping...
# Processing Record 11 of Set 10 | kosa
# Processing Record 12 of Set 10 | uchaly
# Processing Record 13 of Set 10 | esso
# Processing Record 14 of Set 10 | aleksandrov gay
# Processing Record 15 of Set 10 | natal
# Processing Record 16 of Set 10 | muros
# Processing Record 17 of Set 10 | vanimo
# Processing Record 18 of Set 10 | rypefjord
# Processing Record 19 of Set 10 | oneonta
# Processing Record 20 of Set 10 | lazaro cardenas
# Processing Record 21 of Set 10 | narsaq
# Processing Record 22 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 10 | shingu
# Processing Record 24 of Set 10 | obo
# Processing Record 25 of Set 10 | cascais
# Processing Record 26 of Set 10 | baykit
# Processing Record 27 of Set 10 | praia
# Processing Record 28 of Set 10 | zyryanka
# Processing Record 29 of Set 10 | athabasca
# Processing Record 30 of Set 10 | cikampek
# Processing Record 31 of Set 10 | misratah
# Processing Record 32 of Set 10 | madimba
# Processing Record 33 of Set 10 | belyy yar
# Processing Record 34 of Set 10 | ichnya
# Processing Record 35 of Set 10 | langangen
# City not found. Skipping...
# Processing Record 36 of Set 10 | wahiawa
# Processing Record 37 of Set 10 | the valley
# Processing Record 38 of Set 10 | wattegama
# Processing Record 39 of Set 10 | kashi
# Processing Record 40 of Set 10 | mirnyy
# Processing Record 41 of Set 10 | shanghai
# Processing Record 42 of Set 10 | corowa
# Processing Record 43 of Set 10 | matagami
# Processing Record 44 of Set 10 | wajid
# Processing Record 45 of Set 10 | lebu
# Processing Record 46 of Set 10 | sioux lookout
# Processing Record 47 of Set 10 | kismayo
# Processing Record 48 of Set 10 | portland
# Processing Record 49 of Set 10 | kaseda
# Processing Record 50 of Set 10 | ustye
# Processing Record 1 of Set 11 | wakefield
# Processing Record 2 of Set 11 | trofaiach
# Processing Record 3 of Set 11 | shebunino
# Processing Record 4 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 5 of Set 11 | maceio
# Processing Record 6 of Set 11 | adrar
# Processing Record 7 of Set 11 | la ronge
# Processing Record 8 of Set 11 | korla
# Processing Record 9 of Set 11 | nhulunbuy
# Processing Record 10 of Set 11 | pokhara
# Processing Record 11 of Set 11 | shitkino
# Processing Record 12 of Set 11 | saint-augustin
# Processing Record 13 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 11 | amalapuram
# Processing Record 15 of Set 11 | orange walk
# Processing Record 16 of Set 11 | quixada
# Processing Record 17 of Set 11 | yaksatovo
# Processing Record 18 of Set 11 | arkhangelsk
# Processing Record 19 of Set 11 | concordia
# Processing Record 20 of Set 11 | ondjiva
# Processing Record 21 of Set 11 | benghazi
# Processing Record 22 of Set 11 | sept-iles
# Processing Record 23 of Set 11 | najibabad
# Processing Record 24 of Set 11 | jalu
# Processing Record 25 of Set 11 | luorong
# Processing Record 26 of Set 11 | sayaxche
# Processing Record 27 of Set 11 | saint-joseph
# Processing Record 28 of Set 11 | pochutla
# Processing Record 29 of Set 11 | hasaki
# Processing Record 30 of Set 11 | kodala
# Processing Record 31 of Set 11 | along
# Processing Record 32 of Set 11 | planadas
# Processing Record 33 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 11 | notre-dame-du-lac
# Processing Record 35 of Set 11 | saint anthony
# Processing Record 36 of Set 11 | severnyy
# Processing Record 37 of Set 11 | tommot
# Processing Record 38 of Set 11 | hamilton
# Processing Record 39 of Set 11 | markova
# Processing Record 40 of Set 11 | chokwe
# Processing Record 41 of Set 11 | teguise
# Processing Record 42 of Set 11 | kuvandyk
# Processing Record 43 of Set 11 | tourlaville
# Processing Record 44 of Set 11 | taywarah
# Processing Record 45 of Set 11 | volkhov
# Processing Record 46 of Set 11 | kholtoson
# Processing Record 47 of Set 11 | meadow lake
# Processing Record 48 of Set 11 | godda
# Processing Record 49 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 11 | saint-francois
# Processing Record 1 of Set 12 | mbini
# Processing Record 2 of Set 12 | praya
# Processing Record 3 of Set 12 | newcastle
# Processing Record 4 of Set 12 | leningradskiy
# Processing Record 5 of Set 12 | caravelas
# Processing Record 6 of Set 12 | abalak
# Processing Record 7 of Set 12 | cabinda
# Processing Record 8 of Set 12 | naze
# Processing Record 9 of Set 12 | zhangjiakou
# Processing Record 10 of Set 12 | ostersund
# Processing Record 11 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 12 | nedjo
# Processing Record 13 of Set 12 | rabo de peixe
# Processing Record 14 of Set 12 | praia da vitoria
# Processing Record 15 of Set 12 | aasiaat
# Processing Record 16 of Set 12 | rumuruti
# Processing Record 17 of Set 12 | werda
# Processing Record 18 of Set 12 | castlebar
# Processing Record 19 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 20 of Set 12 | pavlovka
# Processing Record 21 of Set 12 | linxia
# Processing Record 22 of Set 12 | magadan
# Processing Record 23 of Set 12 | santiago del estero
# Processing Record 24 of Set 12 | kahului
# Processing Record 25 of Set 12 | trincomalee
# Processing Record 26 of Set 12 | charters towers
# Processing Record 27 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 12 | scottsboro
# Processing Record 29 of Set 12 | macae
# Processing Record 30 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 12 | karasjok
# Processing Record 32 of Set 12 | char bhadrasan
# Processing Record 33 of Set 12 | black river
# Processing Record 34 of Set 12 | upington
# Processing Record 35 of Set 12 | el faiyum
# City not found. Skipping...
# Processing Record 36 of Set 12 | hornepayne
# Processing Record 37 of Set 12 | neiafu
# Processing Record 38 of Set 12 | norfolk
# Processing Record 39 of Set 12 | amahai
# Processing Record 40 of Set 12 | catia la mar
# Processing Record 41 of Set 12 | dicabisagan
# Processing Record 42 of Set 12 | columbus
# Processing Record 43 of Set 12 | simao
# Processing Record 44 of Set 12 | beringovskiy
# Processing Record 45 of Set 12 | chara
# Processing Record 46 of Set 12 | zaozerne
# Processing Record 47 of Set 12 | lorengau
# Processing Record 48 of Set 12 | sumkino
# Processing Record 49 of Set 12 | parrita
# Processing Record 50 of Set 12 | high rock
# Processing Record 1 of Set 13 | oistins
# Processing Record 2 of Set 13 | ous
# Processing Record 3 of Set 13 | thinadhoo
# Processing Record 4 of Set 13 | coffs harbour
# Processing Record 5 of Set 13 | maromitsa
# Processing Record 6 of Set 13 | campbell river
# Processing Record 7 of Set 13 | chicama
# Processing Record 8 of Set 13 | vanavara
# Processing Record 9 of Set 13 | uppiliapuram
# City not found. Skipping...
# Processing Record 10 of Set 13 | awbari
# Processing Record 11 of Set 13 | kuloy
# Processing Record 12 of Set 13 | bougouni
# Processing Record 13 of Set 13 | salinopolis
# Processing Record 14 of Set 13 | gazni
# City not found. Skipping...
# Processing Record 15 of Set 13 | omaruru
# Processing Record 16 of Set 13 | general pico
# Processing Record 17 of Set 13 | sidney
# Processing Record 18 of Set 13 | yanam
# Processing Record 19 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | farsund
# Processing Record 21 of Set 13 | nouadhibou
# Processing Record 22 of Set 13 | aybak
# City not found. Skipping...
# Processing Record 23 of Set 13 | kilindoni
# Processing Record 24 of Set 13 | sao raimundo nonato
# Processing Record 25 of Set 13 | bereda
# Processing Record 26 of Set 13 | zelenogorskiy
# Processing Record 27 of Set 13 | oruro
# Processing Record 28 of Set 13 | nautla
# Processing Record 29 of Set 13 | fuyu
# Processing Record 30 of Set 13 | canazas
# Processing Record 31 of Set 13 | pella
# Processing Record 32 of Set 13 | napier
# Processing Record 33 of Set 13 | nampula
# Processing Record 34 of Set 13 | sahuaripa
# Processing Record 35 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 36 of Set 13 | barretos
# Processing Record 37 of Set 13 | tondano
# Processing Record 38 of Set 13 | san luis
# Processing Record 39 of Set 13 | egvekinot
# Processing Record 40 of Set 13 | ewa beach
# Processing Record 41 of Set 13 | mayumba
# Processing Record 42 of Set 13 | rosarito
# Processing Record 43 of Set 13 | kizukuri
# Processing Record 44 of Set 13 | bloomsburg
# Processing Record 45 of Set 13 | murud
# Processing Record 46 of Set 13 | ahuimanu
# Processing Record 47 of Set 13 | holme
# Processing Record 48 of Set 13 | dasoguz
# Processing Record 49 of Set 13 | sitka
# Processing Record 50 of Set 13 | qadirpur ran
# Processing Record 1 of Set 14 | matrei
# City not found. Skipping...
# Processing Record 2 of Set 14 | nepomuk
# Processing Record 3 of Set 14 | shahr-e babak
# Processing Record 4 of Set 14 | saint andrews
# Processing Record 5 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 14 | adilcevaz
# Processing Record 7 of Set 14 | qasigiannguit
# Processing Record 8 of Set 14 | agva
# City not found. Skipping...
# Processing Record 9 of Set 14 | labuhan
# Processing Record 10 of Set 14 | havelock
# Processing Record 11 of Set 14 | huaicheng
# Processing Record 12 of Set 14 | buraydah
# Processing Record 13 of Set 14 | puerto leguizamo
# Processing Record 14 of Set 14 | ilulissat
# Processing Record 15 of Set 14 | qitaihe
# Processing Record 16 of Set 14 | sorong
# Processing Record 17 of Set 14 | katastarion
# Processing Record 18 of Set 14 | homer
# Processing Record 19 of Set 14 | paytug
# City not found. Skipping...
# Processing Record 20 of Set 14 | pajapan
# Processing Record 21 of Set 14 | harper
# Processing Record 22 of Set 14 | bairiki
# Processing Record 23 of Set 14 | hami
# Processing Record 24 of Set 14 | jibuti
# Processing Record 25 of Set 14 | luga
# Processing Record 26 of Set 14 | balkanabat
# Processing Record 27 of Set 14 | tuskegee
# Processing Record 28 of Set 14 | santa rosa
# Processing Record 29 of Set 14 | zeya
# Processing Record 30 of Set 14 | chortkiv
# Processing Record 31 of Set 14 | horconcitos
# Processing Record 32 of Set 14 | olinda
# Processing Record 33 of Set 14 | dandeli
# Processing Record 34 of Set 14 | sumenep
# Processing Record 35 of Set 14 | dawlatabad
# Processing Record 36 of Set 14 | gushikawa
# Processing Record 37 of Set 14 | prachuap khiri khan
# Processing Record 38 of Set 14 | aykhal
# Processing Record 39 of Set 14 | goya
# Processing Record 40 of Set 14 | cozumel
# Processing Record 41 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 14 | geraldton
# Processing Record 43 of Set 14 | kulaman
# Processing Record 44 of Set 14 | balaipungut
# Processing Record 45 of Set 14 | flin flon
# Processing Record 46 of Set 14 | gidole
# Processing Record 47 of Set 14 | balimo
# City not found. Skipping...
# Processing Record 48 of Set 14 | presidente medici
# Processing Record 49 of Set 14 | murray bridge
# Processing Record 50 of Set 14 | mattawa
# Processing Record 1 of Set 15 | mahon
# Processing Record 2 of Set 15 | tungor
# Processing Record 3 of Set 15 | tromso
# Processing Record 4 of Set 15 | tura
# Processing Record 5 of Set 15 | dumas
# Processing Record 6 of Set 15 | gorey
# Processing Record 7 of Set 15 | haapiti
# Processing Record 8 of Set 15 | beloha
# Processing Record 9 of Set 15 | mana
# Processing Record 10 of Set 15 | erenhot
# Processing Record 11 of Set 15 | bataraza
# City not found. Skipping...
# Processing Record 12 of Set 15 | gat
# Processing Record 13 of Set 15 | jasper
# Processing Record 14 of Set 15 | tumut
# Processing Record 15 of Set 15 | oktyabrskoye
# Processing Record 16 of Set 15 | bubaque
# Processing Record 17 of Set 15 | linjiang
# Processing Record 18 of Set 15 | richards bay
# Processing Record 19 of Set 15 | kailua
# Processing Record 20 of Set 15 | arklow
# Processing Record 21 of Set 15 | kobryn
# Processing Record 22 of Set 15 | kuah
# Processing Record 23 of Set 15 | mogwase
# Processing Record 24 of Set 15 | ust-nera
# Processing Record 25 of Set 15 | rawson
# Processing Record 26 of Set 15 | bytow
# Processing Record 27 of Set 15 | tynaarlo
# Processing Record 28 of Set 15 | bindki
# Processing Record 29 of Set 15 | huarmey
# Processing Record 30 of Set 15 | avera
# Processing Record 31 of Set 15 | osinki
# Processing Record 32 of Set 15 | yar-sale
# Processing Record 33 of Set 15 | cabedelo
# Processing Record 34 of Set 15 | shahjahanpur
# Processing Record 35 of Set 15 | warri
# Processing Record 36 of Set 15 | saint-pierre
# Processing Record 37 of Set 15 | pryazha
# Processing Record 38 of Set 15 | kigoma
# Processing Record 39 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 40 of Set 15 | montepuez
# Processing Record 41 of Set 15 | marau
# Processing Record 42 of Set 15 | bonavista
# Processing Record 43 of Set 15 | say
# Processing Record 44 of Set 15 | oil city
# Processing Record 45 of Set 15 | nelson bay
# Processing Record 46 of Set 15 | merrill
# Processing Record 47 of Set 15 | lata
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Lagoa      PT  39.0500  -27.9833     61.23        66         100
# 1     Tasiilaq      GL  65.6145  -37.6368     39.36        63         100
# 2      Rikitea      PF -23.1203 -134.9692     75.85        80          67
# 3        Yatou      CN  37.1500  122.3833     37.11        42          96
# 4      Ushuaia      AR -54.8000  -68.3000     47.30        88          71
# 5         Ugra      RU  54.7777   34.3267     28.78        92         100
# 6      Mataura      NZ -46.1927  168.8643     55.47        45           0
# 7  Kloulklubed      PW   7.0419  134.2556     84.40        77          58
# 8   Kolondieba      ML  11.0882   -6.8926     68.94        17          89
# 9       Palana      RU  59.1167  159.9667     14.27        86         100
#
#    Wind Speed Current Description
# 0       21.61     overcast clouds
# 1       27.83     overcast clouds
# 2       12.19          light rain
# 3       20.15     overcast clouds
# 4        0.38       broken clouds
# 5        7.58     overcast clouds
# 6        4.14           clear sky
# 7       12.68          light rain
# 8        3.62     overcast clouds
# 9        8.88     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
